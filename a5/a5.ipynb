# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
life_df = pd.read_csv('/content/Life_Expectancy_Data.csv')
life_df.fillna(0, inplace=True)
life_df.head(3)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0              263
# 1      Albania  2015  Developing              77.8               74
# 2      Algeria  2015  Developing              75.6               19
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1              0     4.60              364.975229         99.0        0  ...
# 2             21     0.00                0.000000         95.0       63  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0      6               8.16           65        0.1   584.25921  33736494.0
# 1     99               6.00           99        0.1  3954.22783     28873.0
# 2     95               0.00           95        0.1  4132.76292  39871528.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# ...

# %%
sns.violinplot(data=life_df, y='Polio', inner='quart').set_title('% Polio inoculation Coverage')
# Out:
# Text(0.5, 1.0, '% Polio inoculation Coverage')

# %%
sns.violinplot(data=life_df, y='Diphtheria ', inner='quart').set_title('% Diphtheria inoculation Coverage')
# Out:
# Text(0.5, 1.0, '% Diphtheria inoculation Coverage')

# %%
heat_df = life_df.drop(['Country', 'Year', 'Status'], axis=1)
corr = heat_df.corr()
sns.heatmap(corr, cmap='RdBu')
# Out:
# <Axes: >

# %%
life_df.sort_values(by=['Life expectancy ']).head(10)
# Out:
#                       Country  Year      Status  Life expectancy   \
# 143              Sierra Leone  2015  Developing              51.0
# 3                      Angola  2015  Developing              52.4
# 32   Central African Republic  2015  Developing              52.5
# 33                       Chad  2015  Developing              53.1
# 27              Côte d'Ivoire  2015  Developing              53.3
# 92                    Lesotho  2015  Developing              53.7
# 118                   Nigeria  2015  Developing              54.5
# 148                   Somalia  2015  Developing              55.0
# 150               South Sudan  2015  Developing              57.3
# 30                   Cameroon  2015  Developing              57.3
#
#      Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 143              413             22      0.0                     0.0
# 3                335             66      0.0                     0.0
# ...

# %%
life_df.sort_values(by='Life expectancy ', ascending = False).head(10)
# Out:
#          Country  Year      Status  Life expectancy   Adult Mortality  \
# 146     Slovenia  2015   Developed              88.0               74
# 46       Denmark  2015   Developed              86.0               71
# 42        Cyprus  2015   Developed              85.0               52
# 34         Chile  2015  Developing              85.0               82
# 82         Japan  2015   Developed              83.7               55
# 157  Switzerland  2015   Developed              83.4               49
# 144    Singapore  2015   Developed              83.1               55
# 151        Spain  2015   Developed              82.8               56
# 7      Australia  2015   Developed              82.8               59
# 80         Italy  2015   Developed              82.7               56
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 146              0     0.00                     0.0          0.0       18
# ...

# %%
heat_df.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths     Alcohol  \
# count        183.000000       183.000000     183.000000  183.000000
# mean          71.616940       152.863388      23.803279    0.173388
# std            8.123706        97.561184      83.683762    1.157463
# min           51.000000         1.000000       0.000000    0.000000
# 25%           65.750000        74.000000       0.000000    0.000000
# 50%           73.900000       138.000000       2.000000    0.000000
# 75%           76.950000       213.000000      17.000000    0.000000
# max           88.000000       484.000000     910.000000   10.660000
#
#        percentage expenditure  Hepatitis B       Measles        BMI   \
# count              183.000000   183.000000    183.000000  183.000000
# mean                 2.383906    78.371585   1502.901639   42.286885
# std                 27.461032    29.450716   7842.394928   21.049075
# min                  0.000000     0.000000      0.000000    0.000000
# ...
